# %%
import os

import torch
from datasets import ClassLabel, load_dataset, load_metric
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding

os.environ["WANDB_DISABLED"] = "true"

# %%
raw_datasets = load_dataset('csv', data_files='dataset.csv')['train'].train_test_split(test_size=0.1)
raw_datasets
# Out:
# Using custom data configuration default-ef1d1d836b21f3db
# Reusing dataset csv (/home/veselin/.cache/huggingface/datasets/csv/default-ef1d1d836b21f3db/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'video_id', 'text', 'label'],
#         num_rows: 193716
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'video_id', 'text', 'label'],
#         num_rows: 21525
#     })
# })

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/194 [00:00<?, ?ba/s]
#   0%|          | 0/22 [00:00<?, ?ba/s]

# %%
cleaned_datasets = tokenized_datasets.remove_columns(['Unnamed: 0', 'text', 'video_id'])
cleaned_datasets = cleaned_datasets.class_encode_column('label')
train_dataset = cleaned_datasets['train']
test_dataset = cleaned_datasets['test']

small_train_dataset = train_dataset.shuffle(seed=42).select(range(1000))
small_eval_dataset = test_dataset.shuffle(seed=42).select(range(1000))
# Out:
# Casting to class labels:   0%|          | 0/194 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/20 [00:00<?, ?ba/s]
# Casting to class labels:   0%|          | 0/22 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
torch.cuda.empty_cache()
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
training_args = TrainingArguments(output_dir="trained", per_device_train_batch_size=6, save_total_limit=5, save_steps=5_000)
metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using the `WAND_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the latest cached version of the module from /home/veselin/.cache/huggingface/modules/datasets_modules/metrics/accuracy/bbddc2dafac9b46b0aeeb39c145af710c55e03b223eae89dfe86388f40d9d157 (last modified on Sat May  7 21:39:01 2022) since it couldn't be found locally at accuracy, or remotely on the Hugging Face Hub.

# %%
trainer.train()
# Out:
# /home/veselin/.local/share/virtualenvs/NLU-S1NbPIk9/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 193716
#   Num Epochs = 3
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 1
#   Total optimization steps = 96858
#     <div>
#
#       <progress value='20854' max='96858' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20854/96858 3:21:22 < 12:14:00, 1.73 it/s, Epoch 0.65/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.340100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.284200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.271600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.249000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.280400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.262900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.227100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.219800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.238400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.224900</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.251700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.239400</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.219500</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.223300</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.225600</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.198000</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.233300</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.223400</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.210600</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.231400</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.225500</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.211800</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.188600</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.206400</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.227200</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.229700</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.233500</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.238800</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.209200</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.218800</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.225100</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.213900</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.246700</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.243200</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.220500</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.204700</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.255200</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.254800</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.232700</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.218000</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.220400</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to trained/checkpoint-5000
# Configuration saved in trained/checkpoint-5000/config.json
# Model weights saved in trained/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to trained/checkpoint-10000
# Configuration saved in trained/checkpoint-10000/config.json
# Model weights saved in trained/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to trained/checkpoint-15000
# Configuration saved in trained/checkpoint-15000/config.json
# Model weights saved in trained/checkpoint-15000/pytorch_model.bin
# Saving model checkpoint to trained/checkpoint-20000
# Configuration saved in trained/checkpoint-20000/config.json
# Model weights saved in trained/checkpoint-20000/pytorch_model.bin
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 trainer.train()
#
# File ~/.local/share/virtualenvs/NLU-S1NbPIk9/lib/python3.8/site-packages/transformers/trainer.py:1424, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1421 else:
#    1422     tr_loss_step = self.training_step(model, inputs)
# -> 1424 if (
#    1425     args.logging_nan_inf_filter
#    1426     and not is_torch_tpu_available()
#    1427     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1428 ):
#    1429     # if loss is nan or inf simply add the average of previous logged losses
#    1430     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#    1431 else:
#
# RuntimeError: CUDA error: the launch timed out and was terminated
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
trained = AutoModelForSequenceClassification.from_pretrained('./trained/checkpoint-20000')
i = 0
for example in small_eval_dataset.remove_columns('label'):
    print(tokenizer.decode(example['input_ids']))
    example = { k: torch.tensor([v]) for k, v in example.items() }
    outputs = trained(**example)
    predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
    torch.set_printoptions(precision=30)
    print(predictions)
    i += 1
    if i > 5:
        break
# Out:
# [CLS] something that i begin within 24 hours of a new sets release and our newest set magic the gathering adventures in the forgotten realms of dungeons and dragons mtg set trademark just released and i realized oh no i better start my predictions for the fall set before preview for that set inevitably begins i didn't even get to make a prediction video for the dungeons and dragons magic set because previews began erupting all over the place so soon after modern horizons 2 that it was simply pointless for me to do so this video won't even be able to be edited and up until maybe midweek so for all i know a whole ton of previews for innistrad will already have begun i mean it's been a week without previews gotta get rolling on the next set right no time to enjoy this set hey remember call time remember strictsaven strictsaven no neither do i i mean previews seem to have unintentionally started with the possible oopsie of registered trademarks being discovered for a return to dominaria and kamigawa neon destiny totally called cyberpunk kamigawa by the way and perhaps have even started for innistrad with the leaked but not really leaked accidental preview of an innistrad legendary that was included in someone's dnd commander precon don't worry i'm not showing the leaked card i don't do leaked cards i don't i don't care but if you want to see it available hang on i'll tell you where you can find it uh so if you are interested in seeing the leaked card it's on the internet hope that helps go nuts goodness it just wouldn't be a new magic the gathering preview season without leaks leaks would it i think wizards of the coast needs to start taking their internet safety and password management seriously possibly [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.992237865924835205078125000000, 0.007762140594422817230224609375]],
#        grad_fn=<SoftmaxBackward0>)
# [CLS] now next up here we have a really interesting plug - in it actually turns everything into gems gem sky gem people gem pizza ah wait no i've just been playing gemstone legends so thank you so much to gemstone legends for sponsoring today's video gemstone legends is a hybrid between a puzzle game and an adventure rpg it's a very interesting combo but it's actually pretty fun it actually has a very unique battle system that requires you to complete puzzles to do damage in attack attack so you'll drag gems around your board complete rows get big combos you can even drag the gems diagonally so as you complete battles you're gonna level up your heroes heroes and unlock new areas so as you progress in the game you're gonna move around the map with hex tiles which is pretty reminiscent of old school rpgs but it also allows a lot of freedom in progression there are a ton of different heroes to choose from and they're all hand drawn as well so there's quite a lot of detail here and you look very good so if you want to find me in game i'll be under the nickname flipping osrs and if you want to give gemstone legends a try today you can use the link in my description description the pin comment or even this convenient qr code to install the game and if you install it with my link you're going to get a huge new player bonus worth 50 to claim it you just have to put in the code hashtag flipping in the global chat and thanks once again to gemstone legends for supporting the channel channel and sponsoring today's video [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.003025380196049809455871582031, 0.996974587440490722656250000000]],
#        grad_fn=<SoftmaxBackward0>)
# [CLS] but uh my sponsor my bookie like you you could place bets on the football season coming up right and they have this promotion going on right now to place a bet on this upcoming game cowboys versus buccaneers you're betting if somebody scores scores yeah okay if somebody scores you win you can bet up to 27 and 50 cents right but if either team scores any points whatsoever you win and also up to a thousand dollars my bookie will match your first deposit you deposit 500 they'll give you 500 you deposit a thousand they'll give you a thousand more to bet with as long as you are using code key but to bet on this game that's a no - brainer the last time a game an nfl game ended with zero zero where nobody scored was back in world war ii so ladies and gentlemen click the link down in the [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.002715835114941000938415527344, 0.997284173965454101562500000000]],
#        grad_fn=<SoftmaxBackward0>)
# [CLS] - okay. probably. - get in the box. the giveaway link is down in the description, and huge thanks to t - mobile and oneplus for putting this on. and thanks to dez for helping me out. - you're welcome! - thanks a ton for watching. i'll see you around. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.004693360067903995513916015625, 0.995306670665740966796875000000]],
#        grad_fn=<SoftmaxBackward0>)
# [CLS] when it comes down i won't see you on league play i'll be much higher division two and six in a pub but league play is still pubs you got a out in a pub by a washed up stream you're also being watched up in my industry means i'm gonna retire with millions in the bank let's say my dick suck my lick my nuts he seems feisty and feisty dudes just eat booty like no other you know i got to meet me some feisty dudes not a big fan of this map either what is this one sub penis literal garbage it's like one of my favorite maps to just get killed on you know what i mean i thought this is some penis oh you probably said that loads of times yeah it is something it's a penis they patched the ability to get out of the map again wait there's you can get out of the map yeah you're being a fiber no no i'm not you want to see it oh my god jordan jordan come here i don't know if they fixed it ready and then you just jump into the wall and see you later hey watch oh my god oh no interesting strategy have some free game sense other side's got a bomb on me now shotguns pick them up yes yes yeah make me feel [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.992854654788970947265625000000, 0.007145339157432317733764648438]],
#        grad_fn=<SoftmaxBackward0>)
# [CLS] ( chips clank ) - yatzy! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# tensor([[0.935834825038909912109375000000, 0.064165204763412475585937500000]],
#        grad_fn=<SoftmaxBackward0>)

# %%
import pandas as pd
import itertools

videos = list(itertools.islice(pd.read_json('../data.1.json.gz', orient='record', compression='infer').itertuples(index=False, name=None), 10))

# %%
def window(seq, n):
    it = iter(seq)
    result = tuple(itertools.islice(it, n))
    if len(result) == n:
        yield result
    for elem in it:
        result = result[1:] + (elem,)
        yield result
        
for captions in window(videos[2][1], 5):
    text = ' '.join((caption['text'] for caption in captions))
    inputs = tokenize_function({ 'text': text })
    inputs = { k: torch.tensor([v]) for k, v in inputs.items() }
    outputs = trained(**inputs)
    non_sponsor, sponsor = torch.nn.functional.softmax(outputs.logits, dim=-1).tolist()[0]
    
    print({ 'non_sponsor': '%.2f' % non_sponsor, 'sponsor': '%.2f' % sponsor }, text)
# Out:
# {'non_sponsor': '0.99', 'sponsor': '0.01'} oh my god  i'm holding my life back in my hands
#  right now it feels like this is the only
#  good thing that being severely anemic
# has ever done for me
# {'non_sponsor': '0.99', 'sponsor': '0.01'}  i'm holding my life back in my hands
#  right now it feels like this is the only
#  good thing that being severely anemic
# has ever done for me [Music]
# {'non_sponsor': '0.99', 'sponsor': '0.01'} i'm holding my life back in my hands
#  right now it feels like this is the only
#  good thing that being severely anemic
# has ever done for me [Music]
# {'non_sponsor': '0.99', 'sponsor': '0.01'} right now it feels like this is the only
#  good thing that being severely anemic
# has ever done for me [Music]  okay wait actually before we go to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} good thing that being severely anemic
# has ever done for me [Music]  okay wait actually before we go to
#  boston i want to tell you guys about the
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} [Music]  okay wait actually before we go to
#  boston i want to tell you guys about the
#  sponsor today's video which is current i
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'}  okay wait actually before we go to
#  boston i want to tell you guys about the
#  sponsor today's video which is current i
#  mean it's a way that i'm paying for this
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} okay wait actually before we go to
#  boston i want to tell you guys about the
#  sponsor today's video which is current i
#  mean it's a way that i'm paying for this
#  entire trip in general so it might as
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} boston i want to tell you guys about the
#  sponsor today's video which is current i
#  mean it's a way that i'm paying for this
#  entire trip in general so it might as
#  well tell you about how i'm doing this
#
# {'non_sponsor': '0.01', 'sponsor': '0.99'} sponsor today's video which is current i
#  mean it's a way that i'm paying for this
#  entire trip in general so it might as
#  well tell you about how i'm doing this
#  in the first place
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} mean it's a way that i'm paying for this
#  entire trip in general so it might as
#  well tell you about how i'm doing this
#  in the first place
#  while wearing their awesome hat that
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} entire trip in general so it might as
#  well tell you about how i'm doing this
#  in the first place
#  while wearing their awesome hat that
#  they sent me as well current is the new
#
# {'non_sponsor': '0.95', 'sponsor': '0.05'} well tell you about how i'm doing this
#  in the first place
#  while wearing their awesome hat that
#  they sent me as well current is the new
#  way to bank it is truly the future i
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} in the first place
#  while wearing their awesome hat that
#  they sent me as well current is the new
#  way to bank it is truly the future i
#  mean i feel like we're all always
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} while wearing their awesome hat that
#  they sent me as well current is the new
#  way to bank it is truly the future i
#  mean i feel like we're all always
#  dreaming of what the future holds and
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} they sent me as well current is the new
#  way to bank it is truly the future i
#  mean i feel like we're all always
#  dreaming of what the future holds and
#  honestly it is you with this car
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} way to bank it is truly the future i
#  mean i feel like we're all always
#  dreaming of what the future holds and
#  honestly it is you with this car
#  current is a mobile bank with a visa
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} mean i feel like we're all always
#  dreaming of what the future holds and
#  honestly it is you with this car
#  current is a mobile bank with a visa
#  debit card and a real bank account with
#
# {'non_sponsor': '0.01', 'sponsor': '0.99'} dreaming of what the future holds and
#  honestly it is you with this car
#  current is a mobile bank with a visa
#  debit card and a real bank account with
#  no hidden fees and no minimum balance
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} honestly it is you with this car
#  current is a mobile bank with a visa
#  debit card and a real bank account with
#  no hidden fees and no minimum balance
#  requirement current gets you paid
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} current is a mobile bank with a visa
#  debit card and a real bank account with
#  no hidden fees and no minimum balance
#  requirement current gets you paid
#  actually up to two days faster than
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} debit card and a real bank account with
#  no hidden fees and no minimum balance
#  requirement current gets you paid
#  actually up to two days faster than
#  regular cards aka if you normally get
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} no hidden fees and no minimum balance
#  requirement current gets you paid
#  actually up to two days faster than
#  regular cards aka if you normally get
#  paid on fridays with this card you're
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} requirement current gets you paid
#  actually up to two days faster than
#  regular cards aka if you normally get
#  paid on fridays with this card you're
#  actually gonna get paid on wednesdays i
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} actually up to two days faster than
#  regular cards aka if you normally get
#  paid on fridays with this card you're
#  actually gonna get paid on wednesdays i
#  don't know why you wouldn't want that
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} regular cards aka if you normally get
#  paid on fridays with this card you're
#  actually gonna get paid on wednesdays i
#  don't know why you wouldn't want that
#  and with current you also have the
#
# {'non_sponsor': '0.94', 'sponsor': '0.06'} paid on fridays with this card you're
#  actually gonna get paid on wednesdays i
#  don't know why you wouldn't want that
#  and with current you also have the
#  ability to deposit checks from the
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} actually gonna get paid on wednesdays i
#  don't know why you wouldn't want that
#  and with current you also have the
#  ability to deposit checks from the
#  camera on your phone into your bank
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} don't know why you wouldn't want that
#  and with current you also have the
#  ability to deposit checks from the
#  camera on your phone into your bank
#  account they also have a free overdraft
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} and with current you also have the
#  ability to deposit checks from the
#  camera on your phone into your bank
#  account they also have a free overdraft
#  fee for up to a hundred dollars which is
# huge
# {'non_sponsor': '0.96', 'sponsor': '0.04'} ability to deposit checks from the
#  camera on your phone into your bank
#  account they also have a free overdraft
#  fee for up to a hundred dollars which is
# huge huge
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} camera on your phone into your bank
#  account they also have a free overdraft
#  fee for up to a hundred dollars which is
# huge huge
#  and you guys can even earn points from
#
# {'non_sponsor': '0.01', 'sponsor': '0.99'} account they also have a free overdraft
#  fee for up to a hundred dollars which is
# huge huge
#  and you guys can even earn points from
#  your purchases and redeem them for cash
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} fee for up to a hundred dollars which is
# huge huge
#  and you guys can even earn points from
#  your purchases and redeem them for cash
#  and current is the only place where that
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} huge
#  and you guys can even earn points from
#  your purchases and redeem them for cash
#  and current is the only place where that
#  is happening other cool things about
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} and you guys can even earn points from
#  your purchases and redeem them for cash
#  and current is the only place where that
#  is happening other cool things about
#  current is that they have over 55 000
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} your purchases and redeem them for cash
#  and current is the only place where that
#  is happening other cool things about
#  current is that they have over 55 000
#  free atms for you to use they give you
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and current is the only place where that
#  is happening other cool things about
#  current is that they have over 55 000
#  free atms for you to use they give you
#  instant refunds on gas station holes
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} is happening other cool things about
#  current is that they have over 55 000
#  free atms for you to use they give you
#  instant refunds on gas station holes
#  they work with all the major money
#
# {'non_sponsor': '0.45', 'sponsor': '0.55'} current is that they have over 55 000
#  free atms for you to use they give you
#  instant refunds on gas station holes
#  they work with all the major money
#  transferring services like google pay
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} free atms for you to use they give you
#  instant refunds on gas station holes
#  they work with all the major money
#  transferring services like google pay
#  apple pay venmo
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} instant refunds on gas station holes
#  they work with all the major money
#  transferring services like google pay
#  apple pay venmo
#  and the best part about all that is that
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} they work with all the major money
#  transferring services like google pay
#  apple pay venmo
#  and the best part about all that is that
#  it comes with no fees for transferring
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} transferring services like google pay
#  apple pay venmo
#  and the best part about all that is that
#  it comes with no fees for transferring
#  any of your money yeah that's right not
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} apple pay venmo
#  and the best part about all that is that
#  it comes with no fees for transferring
#  any of your money yeah that's right not
#  only do they want you to get your money
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} and the best part about all that is that
#  it comes with no fees for transferring
#  any of your money yeah that's right not
#  only do they want you to get your money
#  faster each week but they also are not
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} it comes with no fees for transferring
#  any of your money yeah that's right not
#  only do they want you to get your money
#  faster each week but they also are not
#  taking it with a ton of stupid fees for
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} any of your money yeah that's right not
#  only do they want you to get your money
#  faster each week but they also are not
#  taking it with a ton of stupid fees for
#  a million different things because
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} only do they want you to get your money
#  faster each week but they also are not
#  taking it with a ton of stupid fees for
#  a million different things because
#  that's just not them and that's not what
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} faster each week but they also are not
#  taking it with a ton of stupid fees for
#  a million different things because
#  that's just not them and that's not what
#  they want to do it takes two minutes to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} taking it with a ton of stupid fees for
#  a million different things because
#  that's just not them and that's not what
#  they want to do it takes two minutes to
#  sign up for current and then your card
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} a million different things because
#  that's just not them and that's not what
#  they want to do it takes two minutes to
#  sign up for current and then your card
#  will ship for free right to your door so
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} that's just not them and that's not what
#  they want to do it takes two minutes to
#  sign up for current and then your card
#  will ship for free right to your door so
#  i don't know what you're waiting for
#
# {'non_sponsor': '0.01', 'sponsor': '0.99'} they want to do it takes two minutes to
#  sign up for current and then your card
#  will ship for free right to your door so
#  i don't know what you're waiting for
#  click the link in my description right
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} sign up for current and then your card
#  will ship for free right to your door so
#  i don't know what you're waiting for
#  click the link in my description right
#  now and get your current card right now
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} will ship for free right to your door so
#  i don't know what you're waiting for
#  click the link in my description right
#  now and get your current card right now
#  and let's get spending
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} i don't know what you're waiting for
#  click the link in my description right
#  now and get your current card right now
#  and let's get spending
#  and now without further ado we're gonna
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} click the link in my description right
#  now and get your current card right now
#  and let's get spending
#  and now without further ado we're gonna
#  go to boston so let's
# [Music]
# {'non_sponsor': '0.96', 'sponsor': '0.04'} now and get your current card right now
#  and let's get spending
#  and now without further ado we're gonna
#  go to boston so let's
# [Music] up go the morning i can't just let you
# {'non_sponsor': '0.96', 'sponsor': '0.04'} and let's get spending
#  and now without further ado we're gonna
#  go to boston so let's
# [Music] up go the morning i can't just let you [Applause]
# {'non_sponsor': '0.95', 'sponsor': '0.05'} and now without further ado we're gonna
#  go to boston so let's
# [Music] up go the morning i can't just let you [Applause] [Applause]
# [Music]
# {'non_sponsor': '0.94', 'sponsor': '0.06'} go to boston so let's
# [Music] up go the morning i can't just let you [Applause] [Applause]
# [Music] go
# {'non_sponsor': '0.94', 'sponsor': '0.06'} up go the morning i can't just let you [Applause] [Applause]
# [Music] go go
#
# {'non_sponsor': '0.95', 'sponsor': '0.05'} [Applause] [Applause]
# [Music] go go
#  okay [ __ ] here i am i am home
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} [Applause]
# [Music] go go
#  okay [ __ ] here i am i am home
#  and i'm so happy to be here i feel like
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} go go
#  okay [ __ ] here i am i am home
#  and i'm so happy to be here i feel like
#  i have not been home in forever and the
#
# {'non_sponsor': '0.95', 'sponsor': '0.05'} go
#  okay [ __ ] here i am i am home
#  and i'm so happy to be here i feel like
#  i have not been home in forever and the
#  fact that when i came home for christmas
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} okay [ __ ] here i am i am home
#  and i'm so happy to be here i feel like
#  i have not been home in forever and the
#  fact that when i came home for christmas
#  you guys obviously didn't get a vlog
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and i'm so happy to be here i feel like
#  i have not been home in forever and the
#  fact that when i came home for christmas
#  you guys obviously didn't get a vlog
#  which means i haven't vlogged here
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} i have not been home in forever and the
#  fact that when i came home for christmas
#  you guys obviously didn't get a vlog
#  which means i haven't vlogged here
#  since last october is crazy to me time
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} fact that when i came home for christmas
#  you guys obviously didn't get a vlog
#  which means i haven't vlogged here
#  since last october is crazy to me time
#  is flying by and i'm so confused
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} you guys obviously didn't get a vlog
#  which means i haven't vlogged here
#  since last october is crazy to me time
#  is flying by and i'm so confused
#  me rory and johnny all decided to come
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} which means i haven't vlogged here
#  since last october is crazy to me time
#  is flying by and i'm so confused
#  me rory and johnny all decided to come
#  home to boston this week just to get a
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} since last october is crazy to me time
#  is flying by and i'm so confused
#  me rory and johnny all decided to come
#  home to boston this week just to get a
#  little bit of a break
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} is flying by and i'm so confused
#  me rory and johnny all decided to come
#  home to boston this week just to get a
#  little bit of a break
#  and see our families but another reason
# {'non_sponsor': '0.99', 'sponsor': '0.01'} me rory and johnny all decided to come
#  home to boston this week just to get a
#  little bit of a break
#  and see our families but another reason
#  why i wanted to come home
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} home to boston this week just to get a
#  little bit of a break
#  and see our families but another reason
#  why i wanted to come home
#  is because boston announced that all of
# the
# {'non_sponsor': '0.99', 'sponsor': '0.01'} little bit of a break
#  and see our families but another reason
#  why i wanted to come home
#  is because boston announced that all of
# the the
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and see our families but another reason
#  why i wanted to come home
#  is because boston announced that all of
# the the
#  arenas and sports and concert venues are
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} why i wanted to come home
#  is because boston announced that all of
# the the
#  arenas and sports and concert venues are
#  opening back up for sports games at a
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} is because boston announced that all of
# the the
#  arenas and sports and concert venues are
#  opening back up for sports games at a
#  very limited capacity and i wanted to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} it is 3 48. i need to leave at five and
#  i need to just pull my life together oh
#  my god i almost just laid on the horn
#  [ __ ] me laying on the horn in the
#  starbucks line right now for no reason
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} i need to just pull my life together oh
#  my god i almost just laid on the horn
#  [ __ ] me laying on the horn in the
#  starbucks line right now for no reason
#  yeah i can't believe i get to go home
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} my god i almost just laid on the horn
#  [ __ ] me laying on the horn in the
#  starbucks line right now for no reason
#  yeah i can't believe i get to go home
#  right now and get ready to go to an
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} [ __ ] me laying on the horn in the
#  starbucks line right now for no reason
#  yeah i can't believe i get to go home
#  right now and get ready to go to an
#  arena and go see something live
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} starbucks line right now for no reason
#  yeah i can't believe i get to go home
#  right now and get ready to go to an
#  arena and go see something live
#  i'm just really happy that things are
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} yeah i can't believe i get to go home
#  right now and get ready to go to an
#  arena and go see something live
#  i'm just really happy that things are
#  starting to pick back up and get normal
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} right now and get ready to go to an
#  arena and go see something live
#  i'm just really happy that things are
#  starting to pick back up and get normal
#  feeling [ __ ] good all right i just
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} arena and go see something live
#  i'm just really happy that things are
#  starting to pick back up and get normal
#  feeling [ __ ] good all right i just
#  got my drink i got
#
# {'non_sponsor': '0.03', 'sponsor': '0.97'} i'm just really happy that things are
#  starting to pick back up and get normal
#  feeling [ __ ] good all right i just
#  got my drink i got
#  a grande vanilla sweet cream cold brew
#
# {'non_sponsor': '0.04', 'sponsor': '0.96'} starting to pick back up and get normal
#  feeling [ __ ] good all right i just
#  got my drink i got
#  a grande vanilla sweet cream cold brew
#  with white mocha and caramel syrup yes
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} feeling [ __ ] good all right i just
#  got my drink i got
#  a grande vanilla sweet cream cold brew
#  with white mocha and caramel syrup yes
#  so much sugar and crap in it but
# {'non_sponsor': '0.99', 'sponsor': '0.01'} got my drink i got
#  a grande vanilla sweet cream cold brew
#  with white mocha and caramel syrup yes
#  so much sugar and crap in it but
#  whatever i do not like the taste of
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} a grande vanilla sweet cream cold brew
#  with white mocha and caramel syrup yes
#  so much sugar and crap in it but
#  whatever i do not like the taste of
#  coffee at all so i like to drown it out
# with
# {'non_sponsor': '0.99', 'sponsor': '0.01'} with white mocha and caramel syrup yes
#  so much sugar and crap in it but
#  whatever i do not like the taste of
#  coffee at all so i like to drown it out
# with with
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} so much sugar and crap in it but
#  whatever i do not like the taste of
#  coffee at all so i like to drown it out
# with with
#  a million different things this is
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} whatever i do not like the taste of
#  coffee at all so i like to drown it out
# with with
#  a million different things this is
#  absolutely hitting the spot this is one
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} coffee at all so i like to drown it out
# with with
#  a million different things this is
#  absolutely hitting the spot this is one
#  of the first vlogs in a very long time
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} with
#  a million different things this is
#  absolutely hitting the spot this is one
#  of the first vlogs in a very long time
#  that i actually feel good about before i
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} a million different things this is
#  absolutely hitting the spot this is one
#  of the first vlogs in a very long time
#  that i actually feel good about before i
#  even pick up my camera and i just know
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} overtime started yet i was still looking
#  at my phone i looked up and we lost
#  hey besties it's like 1 15 in the
# afternoon afternoon
#  the next day me and rory stayed at a
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} at my phone i looked up and we lost
#  hey besties it's like 1 15 in the
# afternoon afternoon
#  the next day me and rory stayed at a
#  hotel right across the street from td
# garden
# {'non_sponsor': '0.98', 'sponsor': '0.02'} hey besties it's like 1 15 in the
# afternoon afternoon
#  the next day me and rory stayed at a
#  hotel right across the street from td
# garden garden
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} afternoon
#  the next day me and rory stayed at a
#  hotel right across the street from td
# garden garden
#  yesterday was wild and inspiring i
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} the next day me and rory stayed at a
#  hotel right across the street from td
# garden garden
#  yesterday was wild and inspiring i
#  really still
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} hotel right across the street from td
# garden garden
#  yesterday was wild and inspiring i
#  really still
#  cannot process the fact that i was just
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} garden
#  yesterday was wild and inspiring i
#  really still
#  cannot process the fact that i was just
#  in a crowd
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} yesterday was wild and inspiring i
#  really still
#  cannot process the fact that i was just
#  in a crowd
#  of people at an arena again like i just
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} really still
#  cannot process the fact that i was just
#  in a crowd
#  of people at an arena again like i just
#  i'm still like what the [ __ ] was that
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} cannot process the fact that i was just
#  in a crowd
#  of people at an arena again like i just
#  i'm still like what the [ __ ] was that
#  was the past year blur
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} in a crowd
#  of people at an arena again like i just
#  i'm still like what the [ __ ] was that
#  was the past year blur
#  and just seeing the arena at only 12 i
# {'non_sponsor': '0.99', 'sponsor': '0.01'} of people at an arena again like i just
#  i'm still like what the [ __ ] was that
#  was the past year blur
#  and just seeing the arena at only 12 i
#  was just like what the [ __ ] is going on
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} i'm still like what the [ __ ] was that
#  was the past year blur
#  and just seeing the arena at only 12 i
#  was just like what the [ __ ] is going on
#  but that was so
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} was the past year blur
#  and just seeing the arena at only 12 i
#  was just like what the [ __ ] is going on
#  but that was so
#  liberating and i cannot wait for you all
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and just seeing the arena at only 12 i
#  was just like what the [ __ ] is going on
#  but that was so
#  liberating and i cannot wait for you all
#  to experience that too like if sports
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} was just like what the [ __ ] is going on
#  but that was so
#  liberating and i cannot wait for you all
#  to experience that too like if sports
#  games are opening back up where you live
# just
# {'non_sponsor': '0.99', 'sponsor': '0.01'} but that was so
#  liberating and i cannot wait for you all
#  to experience that too like if sports
#  games are opening back up where you live
# just just
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} liberating and i cannot wait for you all
#  to experience that too like if sports
#  games are opening back up where you live
# just just
#  just go seriously just blow your [ __ ]
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} to experience that too like if sports
#  games are opening back up where you live
# just just
#  just go seriously just blow your [ __ ]
#  money and go to one just to be in a
#
# {'non_sponsor': '0.89', 'sponsor': '0.11'} games are opening back up where you live
# just just
#  just go seriously just blow your [ __ ]
#  money and go to one just to be in a
#  crowd like that i'm telling you it's
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} that
#  but yeah awesome 10 out of 10 scenery
#  probably talk to you guys tomorrow
#  because i'm really [ __ ] excited about
#  that that's what i'm going to see
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} but yeah awesome 10 out of 10 scenery
#  probably talk to you guys tomorrow
#  because i'm really [ __ ] excited about
#  that that's what i'm going to see
#  all of my friends and go out to eat and
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} probably talk to you guys tomorrow
#  because i'm really [ __ ] excited about
#  that that's what i'm going to see
#  all of my friends and go out to eat and
#  get a hotel and go shopping and
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} because i'm really [ __ ] excited about
#  that that's what i'm going to see
#  all of my friends and go out to eat and
#  get a hotel and go shopping and
#  everything so let's just [ __ ] cut to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} that that's what i'm going to see
#  all of my friends and go out to eat and
#  get a hotel and go shopping and
#  everything so let's just [ __ ] cut to
#  that honestly like let's get to the
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} all of my friends and go out to eat and
#  get a hotel and go shopping and
#  everything so let's just [ __ ] cut to
#  that honestly like let's get to the
#  point let's see my friends again all
#
# {'non_sponsor': '0.97', 'sponsor': '0.03'} get a hotel and go shopping and
#  everything so let's just [ __ ] cut to
#  that honestly like let's get to the
#  point let's see my friends again all
#  right here we go
#
# {'non_sponsor': '0.98', 'sponsor': '0.02'} everything so let's just [ __ ] cut to
#  that honestly like let's get to the
#  point let's see my friends again all
#  right here we go
#  like bring it on um if you can't tell
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} that honestly like let's get to the
#  point let's see my friends again all
#  right here we go
#  like bring it on um if you can't tell
#  the three of us are back and better
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} point let's see my friends again all
#  right here we go
#  like bring it on um if you can't tell
#  the three of us are back and better
#  we're literally here to cause some
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} right here we go
#  like bring it on um if you can't tell
#  the three of us are back and better
#  we're literally here to cause some
#  issues we just picked james up at
# lululemon
# {'non_sponsor': '0.99', 'sponsor': '0.01'} like bring it on um if you can't tell
#  the three of us are back and better
#  we're literally here to cause some
#  issues we just picked james up at
# lululemon lululemon
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} the three of us are back and better
#  we're literally here to cause some
#  issues we just picked james up at
# lululemon lululemon
#  still there nothing changed so once
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} we're literally here to cause some
#  issues we just picked james up at
# lululemon lululemon
#  still there nothing changed so once
#  again like i say every single time james
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} issues we just picked james up at
# lululemon lululemon
#  still there nothing changed so once
#  again like i say every single time james
#  works at lululemon please don't forget
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} lululemon
#  still there nothing changed so once
#  again like i say every single time james
#  works at lululemon please don't forget
#  it please go harass him
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} still there nothing changed so once
#  again like i say every single time james
# ...
#  rip all my nails off on the flight i
#  would really like to show you the bed
#  sheets i'm sleeping on right now though
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} lax like this what a tragedy maybe i'll
#  rip all my nails off on the flight i
#  would really like to show you the bed
#  sheets i'm sleeping on right now though
#  they're kind of like my childhood bed
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} rip all my nails off on the flight i
#  would really like to show you the bed
#  sheets i'm sleeping on right now though
#  they're kind of like my childhood bed
#  sheets but i kind of forgot what they
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} would really like to show you the bed
#  sheets i'm sleeping on right now though
#  they're kind of like my childhood bed
#  sheets but i kind of forgot what they
#  said on them but
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} sheets i'm sleeping on right now though
#  they're kind of like my childhood bed
#  sheets but i kind of forgot what they
#  said on them but
#  take a good look at these these are
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} they're kind of like my childhood bed
#  sheets but i kind of forgot what they
#  said on them but
#  take a good look at these these are
#  literally hawaii bed sheets
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} sheets but i kind of forgot what they
#  said on them but
#  take a good look at these these are
#  literally hawaii bed sheets
#  that i forgot that i slept on my entire
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} said on them but
#  take a good look at these these are
#  literally hawaii bed sheets
#  that i forgot that i slept on my entire
#  childhood like no [ __ ] [ __ ] i ended
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} take a good look at these these are
#  literally hawaii bed sheets
#  that i forgot that i slept on my entire
#  childhood like no [ __ ] [ __ ] i ended
#  up moving to hawaii and no wonder i'm
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} literally hawaii bed sheets
#  that i forgot that i slept on my entire
#  childhood like no [ __ ] [ __ ] i ended
#  up moving to hawaii and no wonder i'm
#  just absolutely obsessed with it like
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} that i forgot that i slept on my entire
#  childhood like no [ __ ] [ __ ] i ended
#  up moving to hawaii and no wonder i'm
#  just absolutely obsessed with it like
#  these were the bed sheets that i slept
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} childhood like no [ __ ] [ __ ] i ended
#  up moving to hawaii and no wonder i'm
#  just absolutely obsessed with it like
#  these were the bed sheets that i slept
#  on all the time and growing up i'd never
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} up moving to hawaii and no wonder i'm
#  just absolutely obsessed with it like
#  these were the bed sheets that i slept
#  on all the time and growing up i'd never
#  even been to hawaii so i don't know why
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} just absolutely obsessed with it like
#  these were the bed sheets that i slept
#  on all the time and growing up i'd never
#  even been to hawaii so i don't know why
#  my mom chose these but she did
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} these were the bed sheets that i slept
#  on all the time and growing up i'd never
#  even been to hawaii so i don't know why
#  my mom chose these but she did
#  and um this is me saying that like
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} on all the time and growing up i'd never
#  even been to hawaii so i don't know why
#  my mom chose these but she did
#  and um this is me saying that like
#  everything happens for a reason all
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} even been to hawaii so i don't know why
#  my mom chose these but she did
#  and um this is me saying that like
#  everything happens for a reason all
#  right i'm gonna go now that makes me so
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} my mom chose these but she did
#  and um this is me saying that like
#  everything happens for a reason all
#  right i'm gonna go now that makes me so
#  sad i don't want to be ending this vlog
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and um this is me saying that like
#  everything happens for a reason all
#  right i'm gonna go now that makes me so
#  sad i don't want to be ending this vlog
#  at all i like hate that i didn't even
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} everything happens for a reason all
#  right i'm gonna go now that makes me so
#  sad i don't want to be ending this vlog
#  at all i like hate that i didn't even
#  get to like do anything i had to wake up
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} right i'm gonna go now that makes me so
#  sad i don't want to be ending this vlog
#  at all i like hate that i didn't even
#  get to like do anything i had to wake up
#  from the hotel
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} sad i don't want to be ending this vlog
#  at all i like hate that i didn't even
#  get to like do anything i had to wake up
#  from the hotel
#  and go right home and return my rental
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} at all i like hate that i didn't even
#  get to like do anything i had to wake up
#  from the hotel
#  and go right home and return my rental
#  car and i didn't get to go to like
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} get to like do anything i had to wake up
#  from the hotel
#  and go right home and return my rental
#  car and i didn't get to go to like
#  brunch with all my friends i barely even
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} from the hotel
#  and go right home and return my rental
#  car and i didn't get to go to like
#  brunch with all my friends i barely even
#  got to say bye to everyone well i said
# {'non_sponsor': '0.99', 'sponsor': '0.01'} and go right home and return my rental
#  car and i didn't get to go to like
#  brunch with all my friends i barely even
#  got to say bye to everyone well i said
#  bye to everyone last night but like i
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} car and i didn't get to go to like
#  brunch with all my friends i barely even
#  got to say bye to everyone well i said
#  bye to everyone last night but like i
#  didn't get to do anything fun today and
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} brunch with all my friends i barely even
#  got to say bye to everyone well i said
#  bye to everyone last night but like i
#  didn't get to do anything fun today and
#  now i'm just like sad that this is how
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} got to say bye to everyone well i said
#  bye to everyone last night but like i
#  didn't get to do anything fun today and
#  now i'm just like sad that this is how
#  my video is ending like it's just over
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} bye to everyone last night but like i
#  didn't get to do anything fun today and
#  now i'm just like sad that this is how
#  my video is ending like it's just over
#  now but that's okay
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} didn't get to do anything fun today and
#  now i'm just like sad that this is how
#  my video is ending like it's just over
#  now but that's okay
#  because i'll be back wait also don't
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} now i'm just like sad that this is how
#  my video is ending like it's just over
#  now but that's okay
#  because i'll be back wait also don't
#  forget to click the link in my bio to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} my video is ending like it's just over
#  now but that's okay
#  because i'll be back wait also don't
#  forget to click the link in my bio to
#  get your current card today thank you
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} now but that's okay
#  because i'll be back wait also don't
#  forget to click the link in my bio to
#  get your current card today thank you
#  kern for sponsoring i love you
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} because i'll be back wait also don't
#  forget to click the link in my bio to
#  get your current card today thank you
#  kern for sponsoring i love you
#  can't wait to see what mistake i make
#
# {'non_sponsor': '0.00', 'sponsor': '1.00'} forget to click the link in my bio to
#  get your current card today thank you
#  kern for sponsoring i love you
#  can't wait to see what mistake i make
#  with this card next time will only tell
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} get your current card today thank you
#  kern for sponsoring i love you
#  can't wait to see what mistake i make
#  with this card next time will only tell
#  i will see you guys in my next video i
#
# {'non_sponsor': '0.02', 'sponsor': '0.98'} kern for sponsoring i love you
#  can't wait to see what mistake i make
#  with this card next time will only tell
#  i will see you guys in my next video i
#  hope you [ __ ] love this like i did
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} can't wait to see what mistake i make
#  with this card next time will only tell
#  i will see you guys in my next video i
#  hope you [ __ ] love this like i did
#  thank you for everything
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} with this card next time will only tell
#  i will see you guys in my next video i
#  hope you [ __ ] love this like i did
#  thank you for everything
#  so crazy how my life is now compared to
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} i will see you guys in my next video i
#  hope you [ __ ] love this like i did
#  thank you for everything
#  so crazy how my life is now compared to
#  how it was living here and growing up
# here
# {'non_sponsor': '0.99', 'sponsor': '0.01'} hope you [ __ ] love this like i did
#  thank you for everything
#  so crazy how my life is now compared to
#  how it was living here and growing up
# here here
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} thank you for everything
#  so crazy how my life is now compared to
#  how it was living here and growing up
# here here
#  i'm just so [ __ ] grateful like thank
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} so crazy how my life is now compared to
#  how it was living here and growing up
# here here
#  i'm just so [ __ ] grateful like thank
#  you guys for everything in this life
# like
# {'non_sponsor': '0.99', 'sponsor': '0.01'} how it was living here and growing up
# here here
#  i'm just so [ __ ] grateful like thank
#  you guys for everything in this life
# like like
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} here
#  i'm just so [ __ ] grateful like thank
#  you guys for everything in this life
# like like
#  seriously i do not know how i got so
#
# {'non_sponsor': '0.96', 'sponsor': '0.04'} i'm just so [ __ ] grateful like thank
#  you guys for everything in this life
# like like
#  seriously i do not know how i got so
#  lucky and coming home just makes me feel
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} some things planned that i think you
#  guys will like but
#  we'll [ __ ] see no more peace signs i
#  need to end this video i love you guys
#  so much oh my god i went to a sports
#
# {'non_sponsor': '0.99', 'sponsor': '0.01'} guys will like but
#  we'll [ __ ] see no more peace signs i
#  need to end this video i love you guys
#  so much oh my god i went to a sports
#  game in this video holy [ __ ]
# [ __ ]
# {'non_sponsor': '0.98', 'sponsor': '0.02'} we'll [ __ ] see no more peace signs i
#  need to end this video i love you guys
#  so much oh my god i went to a sports
#  game in this video holy [ __ ]
# [ __ ]
# {'non_sponsor': '0.03', 'sponsor': '0.97'} need to end this video i love you guys
#  so much oh my god i went to a sports
#  game in this video holy [ __ ]
# [ __ ]  bring that freaks out i put choices
# through
# {'non_sponsor': '0.01', 'sponsor': '0.99'} so much oh my god i went to a sports
#  game in this video holy [ __ ]
# [ __ ]  bring that freaks out i put choices
# through through
# baby hooded them now

# %%
tc_tokenizer = AutoTokenizer.from_pretrained('dennlinger/roberta-cls-consec')
tc_model = AutoModelForSequenceClassification.from_pretrained('dennlinger/roberta-cls-consec')
# Out:
# Downloading:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dennlinger/roberta-cls-consec were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def group(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return itertools.zip_longest(fillvalue=fillvalue, *args)
        
for left_captions, right_captions in group(group(videos[2][1], 2), 2, []):
    left_text = ' '.join((caption['text'] for caption in left_captions))
    right_text = ' '.join((caption['text'] for caption in right_captions))
    inputs = tc_tokenizer(left_text, right_text)
    inputs = { k: torch.tensor([v]) for k, v in inputs.items() }
    outputs = tc_model(**inputs)
    non_sponsor, sponsor = torch.nn.functional.softmax(outputs.logits, dim=-1).tolist()[0]
    
    print({ 'not_same': '%.2f' % non_sponsor, 'same': '%.2f' % sponsor }, left_text, right_text)
# Out:
# {'not_same': '0.00', 'same': '1.00'} oh my god  i'm holding my life back in my hands
#  right now it feels like this is the only
#
# {'not_same': '0.21', 'same': '0.79'} good thing that being severely anemic
# has ever done for me [Music]  okay wait actually before we go to
#
# {'not_same': '0.28', 'same': '0.72'} boston i want to tell you guys about the
#  sponsor today's video which is current i
#  mean it's a way that i'm paying for this
#  entire trip in general so it might as
#
# {'not_same': '0.03', 'same': '0.97'} well tell you about how i'm doing this
#  in the first place
#  while wearing their awesome hat that
#  they sent me as well current is the new
#
# {'not_same': '0.00', 'same': '1.00'} way to bank it is truly the future i
#  mean i feel like we're all always
#  dreaming of what the future holds and
#  honestly it is you with this car
#
# {'not_same': '0.02', 'same': '0.98'} current is a mobile bank with a visa
#  debit card and a real bank account with
#  no hidden fees and no minimum balance
#  requirement current gets you paid
#
# {'not_same': '0.03', 'same': '0.97'} actually up to two days faster than
#  regular cards aka if you normally get
#  paid on fridays with this card you're
#  actually gonna get paid on wednesdays i
#
# {'not_same': '0.16', 'same': '0.84'} don't know why you wouldn't want that
#  and with current you also have the
#  ability to deposit checks from the
#  camera on your phone into your bank
#
# {'not_same': '0.09', 'same': '0.91'} account they also have a free overdraft
#  fee for up to a hundred dollars which is
# huge huge
#  and you guys can even earn points from
#
# {'not_same': '0.10', 'same': '0.90'} your purchases and redeem them for cash
#  and current is the only place where that
#  is happening other cool things about
#  current is that they have over 55 000
#
# {'not_same': '0.06', 'same': '0.94'} free atms for you to use they give you
#  instant refunds on gas station holes
#  they work with all the major money
#  transferring services like google pay
#
# {'not_same': '0.21', 'same': '0.79'} apple pay venmo
#  and the best part about all that is that
#  it comes with no fees for transferring
#  any of your money yeah that's right not
#
# {'not_same': '0.70', 'same': '0.30'} only do they want you to get your money
#  faster each week but they also are not
#  taking it with a ton of stupid fees for
#  a million different things because
#
# {'not_same': '0.53', 'same': '0.47'} that's just not them and that's not what
#  they want to do it takes two minutes to
#  sign up for current and then your card
#  will ship for free right to your door so
#
# {'not_same': '0.01', 'same': '0.99'} i don't know what you're waiting for
#  click the link in my description right
#  now and get your current card right now
#  and let's get spending
#
# {'not_same': '0.01', 'same': '0.99'} and now without further ado we're gonna
#  go to boston so let's
# [Music] up go the morning i can't just let you [Applause]
# {'not_same': '0.01', 'same': '0.99'} [Applause]
# [Music] go go
#  okay [ __ ] here i am i am home
#
# {'not_same': '0.01', 'same': '0.99'} and i'm so happy to be here i feel like
#  i have not been home in forever and the
#  fact that when i came home for christmas
#  you guys obviously didn't get a vlog
#
# {'not_same': '0.01', 'same': '0.99'} which means i haven't vlogged here
#  since last october is crazy to me time
#  is flying by and i'm so confused
#  me rory and johnny all decided to come
#
# {'not_same': '0.00', 'same': '1.00'} home to boston this week just to get a
#  little bit of a break
#  and see our families but another reason
#  why i wanted to come home
#
# {'not_same': '0.03', 'same': '0.97'} is because boston announced that all of
# the the
#  arenas and sports and concert venues are
#  opening back up for sports games at a
#
# {'not_same': '0.19', 'same': '0.81'} very limited capacity and i wanted to
#  try and come and go to one because at
#  this point i don't care what
#  entertainment i see live i need
#
# {'not_same': '0.08', 'same': '0.92'} something in front of me physically
#  entertaining me in an arena before i
#  lose my goddamn mind
#  and that's what i'm doing today i'm
#
# {'not_same': '0.00', 'same': '1.00'} going to a bruins game with rory and my
#  dad aiden but i'm really excited i don't
#  even think i've ever been to a bruins
# game game
#
# {'not_same': '0.00', 'same': '1.00'} in boston before which is so lame
#  because i'm a football girly i like
#  football i got the patriot sweatshirt on
#  you can hardly see the steering wheel is
#
# {'not_same': '0.00', 'same': '1.00'} seriously just in the way but i'm
#  getting starbucks right now
#  it is 3 48. i need to leave at five and
#  i need to just pull my life together oh
#
# {'not_same': '0.01', 'same': '0.99'} my god i almost just laid on the horn
#  [ __ ] me laying on the horn in the
#  starbucks line right now for no reason
#  yeah i can't believe i get to go home
#
# {'not_same': '0.01', 'same': '0.99'} right now and get ready to go to an
#  arena and go see something live
#  i'm just really happy that things are
#  starting to pick back up and get normal
#
# {'not_same': '0.01', 'same': '0.99'} feeling [ __ ] good all right i just
#  got my drink i got
#  a grande vanilla sweet cream cold brew
#  with white mocha and caramel syrup yes
#
# {'not_same': '0.00', 'same': '1.00'} so much sugar and crap in it but
#  whatever i do not like the taste of
#  coffee at all so i like to drown it out
# with with
#
# {'not_same': '0.00', 'same': '1.00'} a million different things this is
#  absolutely hitting the spot this is one
#  of the first vlogs in a very long time
#  that i actually feel good about before i
#
# {'not_same': '0.00', 'same': '1.00'} even pick up my camera and i just know
#  what i'm gonna
#  do and i know i'm gonna have fun and i
#  know it's gonna be fun to edit and i
#
# {'not_same': '0.01', 'same': '0.99'} know you guys are gonna like it so
#  i am excited i need to go home now
#  though because i have an hour to get
#  ready and i have a cute yellow black and
#
# {'not_same': '0.18', 'same': '0.82'} white outfit picked out for the bruins
# so so
#  let's [ __ ] go
# [Music] [Music]
#
# {'not_same': '0.00', 'same': '1.00'} all right aidan how are you feeling very
#  good exciting
# great answer thank you  all right aidan give me your post game
#
# {'not_same': '0.00', 'same': '1.00'} interview how do you feel
#  we lost i'm not good how do you feel i
#  didn't even know
#  overtime started yet i was still looking
#
# {'not_same': '0.01', 'same': '0.99'} at my phone i looked up and we lost
#  hey besties it's like 1 15 in the
# afternoon afternoon
#  the next day me and rory stayed at a
#
# {'not_same': '0.01', 'same': '0.99'} hotel right across the street from td
# garden garden
#  yesterday was wild and inspiring i
#  really still
#
# {'not_same': '0.01', 'same': '0.99'} cannot process the fact that i was just
#  in a crowd
#  of people at an arena again like i just
#  i'm still like what the [ __ ] was that
#
# {'not_same': '0.00', 'same': '1.00'} was the past year blur
#  and just seeing the arena at only 12 i
#  was just like what the [ __ ] is going on
#  but that was so
#
# {'not_same': '0.02', 'same': '0.98'} liberating and i cannot wait for you all
#  to experience that too like if sports
#  games are opening back up where you live
# just just
#
# {'not_same': '0.00', 'same': '1.00'} just go seriously just blow your [ __ ]
#  money and go to one just to be in a
#  crowd like that i'm telling you it's
#  worth every cent i'm feeling amazing
#
# {'not_same': '0.01', 'same': '0.99'} thriving truly it's friday right now and
#  i leave monday morning and i'm already
#  just like this trip was way too short i
#  need this to be way
#
# {'not_same': '0.00', 'same': '1.00'} longer i'm just so happy to be home and
#  the weather's been nice and everything
#  is just getting better and i'm just
#  feeling optimistic and that's all i can
#
# {'not_same': '0.01', 'same': '0.99'} ask for
#  i just can't stop thinking about this
#  one moment last night where the burns
#  got a gold just the whole arena stood up
#
# {'not_same': '0.01', 'same': '0.99'} at the same time and started screaming
#  and i was just like oh oh wow like a
#  huge serotonin rush
#  right then and there to charge me
#
# {'not_same': '0.00', 'same': '1.00'} serotonin for the next month i don't
#  know what i just said but i said it so
#  we're gonna move on me rory and his dad
#  also went out last night and had some
#
# {'not_same': '0.00', 'same': '1.00'} drinks so that was wholesome that was
# fun fun
#  it just felt normal so i really
#  appreciated that i had so much fun with
# {'not_same': '0.00', 'same': '1.00'} my dad and aiden but now tonight is
#  about my mom
#  i'm going out with her and her friends
#  the ladies are going to go get some
# drinks
# {'not_same': '0.01', 'same': '0.99'} drinks
#  let me show you the view of the hotel
#  room right now i'm sure you really care
#  but i personally appreciate it so i want
#
# {'not_same': '0.00', 'same': '1.00'} you guys to appreciate with me we've got
#  the highway we've got the garden right
#  there oh yeah i lost a nail last night
#  so that's really sad oh my god my nails
#
# {'not_same': '0.03', 'same': '0.97'} so gross actually don't look at it it's
#  kind of gross out kind of annoyed about
# that that
#  but yeah awesome 10 out of 10 scenery
#
# {'not_same': '0.00', 'same': '1.00'} probably talk to you guys tomorrow
#  because i'm really [ __ ] excited about
#  that that's what i'm going to see
#  all of my friends and go out to eat and
#
# {'not_same': '0.00', 'same': '1.00'} get a hotel and go shopping and
#  everything so let's just [ __ ] cut to
#  that honestly like let's get to the
#  point let's see my friends again all
#
# {'not_same': '0.01', 'same': '0.99'} right here we go
#  like bring it on um if you can't tell
#  the three of us are back and better
#  we're literally here to cause some
#
# {'not_same': '0.02', 'same': '0.98'} issues we just picked james up at
# lululemon lululemon
#  still there nothing changed so once
#  again like i say every single time james
#
# {'not_same': '0.06', 'same': '0.94'} works at lululemon please don't forget
#  it please go harass him
#  if you live in the boston area they do
#  yes oh yes okay so everything is normal
#
# {'not_same': '0.01', 'same': '0.99'} you guys are doing your job thank you so
#  much oh really cute dog ahead of me
#  yeah it's going to bathroom we're
#  currently going on a shopping spree
#
# {'not_same': '0.01', 'same': '0.99'} where are we going first
#  brandy because kayla's having me we love
#  that live oh i'm having a meet and greet
#  no in the most literal sense two weeks
#
# {'not_same': '0.00', 'same': '1.00'} ago i bought every single color
#  zip up that brandy has now i have six of
#  them i also have some incredible news we
#  might be making a comeback of mommy made
#
# {'not_same': '0.00', 'same': '1.00'} a mistake
#  might do it today mommy will no we are
# doing  okay he's making a terrible amazing
#
# {'not_same': '0.03', 'same': '0.97'} mistake unclear what the mistake will be
#  exactly but it is happening
#  and it will be very expensive but my tax
#  guy said this morning i can do it so i'm
#
# {'not_same': '0.04', 'same': '0.96'} gonna do it
#  yeah this one hurt you too much jason
#  said go for it so i'm gonna go for it we
#  look really good yeah we look really
#
# {'not_same': '0.01', 'same': '0.99'} good okay i'd be scared if i wasn't
#  honest oh four five i hate that oh my
#  god this line is going to take forever
#  so i go to the front of the line and go
#
# {'not_same': '0.00', 'same': '1.00'} hey i am i know that girl brandi can we
#  just get in there
#  she told me to like text you guys when i
#  was here yeah i was like hey just go to
#
# {'not_same': '0.01', 'same': '0.99'} the front of the line and say hey we're
#  with brandi
#  no i really think so really sad update
#  we did not go to brandy melville the
#
# {'not_same': '0.00', 'same': '1.00'} line was just obnoxiously long now we
#  are going to get a juice because
#  have to eat juice nope drink juice
#  strangers and
#
# {'not_same': '0.00', 'same': '1.00'} so yeah we're doing that and i'm going
#  to go make a mistake somewhere so we'll
#  keep you updated on the place that i
#  choose to make mistake at i almost just
#
# {'not_same': '0.00', 'same': '1.00'} ran into a poll
#  james where are you going jc smoothie
#  are you coming with me oh we've never
#  been there before but we must have run
# hey guys let's go
# {'not_same': '0.01', 'same': '0.99'}  what do they say oh my god here we go
#  not another shot
#  what how was that one going crazy today
#
# {'not_same': '0.03', 'same': '0.97'} it tastes like strawberries and bananas
#  that's what it is well considering it's
# a smoothie i'm gonna have to agree  okay i'm doing something bad we'll keep
#
# {'not_same': '0.02', 'same': '0.98'} you updated there's a mistake being made
#  as we speak i don't know if it's a
#  mistake though actually it was meant to
# happen happen
#
# {'not_same': '0.01', 'same': '0.99'} fight maybe before dude she got a
# manicure manicure
# how about that how are we gonna film  oh no oh no oh no okay one mistake down
#
# {'not_same': '0.02', 'same': '0.98'} might have one more to go
#  one more i might i don't know i'm
#  feeling crazy thank you karen for
# sponsoring this video
# {'not_same': '0.03', 'same': '0.97'} what am i doing i haven't made a mistake
#  in years and i'm doing it right now
#  and one of the three little digits on
#  the back of your card what are those oh
#
# {'not_same': '0.43', 'same': '0.57'} let's shut up
#  shut up right now you know what the guy
#  who does my taxes said i can do this
#  this morning so three
#
# {'not_same': '0.00', 'same': '1.00'} that's great what did i just do i'm
#  gonna pretend that the receipt is an
#  error and that the decimal place is
#  accidentally moved over like right
#
# {'not_same': '0.02', 'same': '0.98'} and it was just 22. yeah yeah oh oh miss
#  girl ole miss girl
#  mommy tell us what you did we went up
#  from the last mistake that i made and
#
# {'not_same': '0.00', 'same': '1.00'} today i made two mistakes at once
#  and now i'm going to a steakhouse i'm
#  also going to steakhouse i'll be there
#  what are you eating maybe salmon i'm
#
# {'not_same': '0.00', 'same': '1.00'} going to go throw up now
#  okay great i'll come with you cool okay
#  let's go come on now with my throat
#  let's go okay so we just checked into
#
# {'not_same': '0.00', 'same': '1.00'} our room and there's blood all over the
#  curtain we've now been upgraded because
#  we don't want a
#  room with um you know this mystery
#
# {'not_same': '0.00', 'same': '1.00'} substance that i'm going to assume is
#  blood she's constantly raising the bar
#  no now we're raising the floor level so
#  here we go unfortunately we have to say
#
# {'not_same': '0.00', 'same': '1.00'} goodbye to our gorgeous view
#  oh no not this okay guys i'm ready to
#  start my haul but i need my lovely
#  assistant james here
#
# {'not_same': '0.00', 'same': '1.00'} hi here we go welcome back to a caitlyn
#  james hall not like we've ever done this
# before before
#  great so welcome to the first yes the
#
# {'not_same': '0.00', 'same': '1.00'} first of many we're planning on having a
#  crazy year crazy summer crazy life okay
#  great i like that you're introduced
#  yeah i'm setting us up for more failures
#
# {'not_same': '0.03', 'same': '0.97'} like this in the future right of course
#  um okay so as we all know mommy made a
#  mistake has come back today
#  and i'd like to present to you two
#
# {'not_same': '0.01', 'same': '0.99'} mistakes that have been made this is
#  very unlike me
#  i bought one thing that i have been
#  begging for for years from myself and
#
# {'not_same': '0.01', 'same': '0.99'} myself finally let myself have it so it
#  was a moment but first drum roll here we
# go  look at the packaging why do i have this
#
# {'not_same': '0.01', 'same': '0.99'} in my hands in general why did i buy
# this this
#  yeah that's the receipt okay so we're
#  totally gonna put the receipt in the
# trash
# {'not_same': '0.01', 'same': '0.99'} trash
#  no kidding don't um there are shoes that
#  have gone viral from gucci and i wanted
#  them last fall
#
# {'not_same': '0.00', 'same': '1.00'} then i decided it was the fall like
#  there's no need to get them because it's
#  going to be the fall
#  so instead i decided to get them now i
#
# {'not_same': '0.80', 'same': '0.20'} was originally planning on getting a
#  paint color but i was talked out of it
#  by my good friend james and my good
#  friend lindsay i now have gucci
#
# {'not_same': '0.00', 'same': '1.00'} jelly flip flops aren't they so cute you
#  guys it's like a fun
#  idea ivory i feel like i'm not gonna
#  take these off ever 24 7. i mean as we
#
# {'not_same': '0.00', 'same': '1.00'} all know i've been in
#  unfortunately multiple paparazzi
#  pictures of me with uggs on oh
#  because i don't really have any other
#
# {'not_same': '0.00', 'same': '1.00'} like flip-flops or sandals right
#  so i'm hoping that this is the upgrade
#  that i need i think it's the upgrade
#  that you need in dessert but for some
#
# {'not_same': '0.01', 'same': '0.99'} reason i know i'm gonna end up wearing
#  my eggs anyways but we can now hold me
#  accountable because i have these don't
#  deserve them should have gotten a
# {'not_same': '0.00', 'same': '1.00'} manicure first
#  i was just about to here they are
#  the next step manicure yes let's just
#  get on that they only would let me have
#
# {'not_same': '0.03', 'same': '0.97'} one shoe again
#  the other one's in a bag but i just
#  don't feel like unboxing that one so
#  that's what i have ready to take on the
#
# {'not_same': '0.01', 'same': '0.99'} summer with these shoes
#  i'm destroying the box with water really
#  good inspirational things oh
# wait look at the real prize
# {'not_same': '0.01', 'same': '0.99'} are you kidding me oh wow i have to pull
#  myself together and you did buy
#  something else
#  i did buy something else i bitched about
#
# {'not_same': '0.00', 'same': '1.00'} this item in this bag for years
#  yes now i do not buy designer bags often
#  i truly only bought one which is my
#  iconic balenciaga that i bought in
# hawaii
# {'not_same': '0.05', 'same': '0.95'} hawaii
#  fall 2019. which one are you wearing
#  tonight i think this
#  this bag has been sold out for a very
#
# {'not_same': '0.40', 'same': '0.60'} long time which is probably been the
#  best for me
#  today we had the unfortunate
#  circumstances of the bag coming back in
# stock
# {'not_same': '0.00', 'same': '1.00'} stock
#  at one location in boston and um guess
#  how many you came back and stopped did
#  you guys guess one because if you did
#
# {'not_same': '0.00', 'same': '1.00'} you were right yeah just one
#  a single one and i i have it and i was
#  kind of bullied i wasn't bullied into
#  getting it come on there was a bully it
#
# {'not_same': '0.01', 'same': '0.99'} was like caitlyn you should get it and
#  she was like you're right i'm gonna get
# it it
#  the only reason why i didn't black out
#
# {'not_same': '0.01', 'same': '0.99'} at the cash register is because i think
#  about this bag 24 7 and if i didn't get
#  it now i would have got it at another
#  point in time because this is the only
#
# {'not_same': '0.03', 'same': '0.97'} bag i think about because because it's
# gorgina gorgina
#  that's james's favorite word for those
#  of you who don't know gorgeous vagina oh
# wow
# {'not_same': '0.02', 'same': '0.98'}  we're going to give more of a reaction
#  to the dust bag of the actual bag
#  everyone give it up for her
#
# {'not_same': '0.02', 'same': '0.98'} here she is ladies and gentlemen yes so
#  this is my new backpack it fits my
#  camera which is why i bought it and
#  which is why i think it is perfect for
# me
# {'not_same': '0.01', 'same': '0.99'} me
#  and now i have an everyday bag that is
#  nice and i can't believe i bought this
#  for myself and i'm confused
#
# {'not_same': '0.00', 'same': '1.00'} you deserve miss girl i worked hard for
#  this bag i'm really proud of myself oh
#  i wanted this for years oh no
#  not the bad falling in the trash
#
# {'not_same': '0.00', 'same': '1.00'} literally just launched her back into
#  the trash her absolutely
#  i just threw my new bag in the trash my
#  battery just died my bag went in the
#
# {'not_same': '0.06', 'same': '0.94'} trash everything's normal it is 6 30
#  right now
#  we are getting ready to go on an
#  adventure have a fabulous night that we
# are
# {'not_same': '0.08', 'same': '0.92'} are
#  a night that we deserve i have to break
#  my bag out in ways that aren't throwing
#  it in the trash
#
# {'not_same': '0.01', 'same': '0.99'} yeah i'm going to change now okay ready
#  here we go i'm going to put this on
#  including my fake boobs one two three
#  here we go
# here we are give it up for us
# {'not_same': '0.01', 'same': '0.99'}  me putting applause in the background
#  without further ado we're now going to
# go to the palm and black out right mike
# {'not_same': '0.01', 'same': '0.99'} all right mike what are you getting at
#  the palm tonight the most expensive
#  steak on the menu
#  and then complain about it later i'm
#
# {'not_same': '0.01', 'same': '0.99'} gonna drink before i order the steak and
# then then
#  i'm gonna complain about it later okay
#  perfect i'm ready to get drunk and have
# fun so here i go
# {'not_same': '0.02', 'same': '0.98'}  so in typical beyonce fashion formation
#  we're getting information and we are
#  going to star market
#
# {'not_same': '0.02', 'same': '0.98'} in less than four minutes because we
#  would like white claws and they close
#  in five minutes so here we go we don't
#  feel like drinking the
#
# {'not_same': '0.02', 'same': '0.98'} boys um whatever it is
#  yeah like captain morgan i'm literally
#  all [ __ ] set so here we go on our
#  adventure to get um white clothes less
#
# {'not_same': '0.00', 'same': '1.00'} than five minutes so here we go we can
#  do it we can
# [Music] [Music]
#  we really said [ __ ] four minutes we'll
# get there in one second
# {'not_same': '0.01', 'same': '0.99'} [Applause] [Applause]
# [Music] [Music]
#  so somehow this week is already over i
#
# {'not_same': '0.00', 'same': '1.00'} literally do not know how um
#  yes i have zit stickers on my face right
#  now i have a big long one here and
#  another big long one here so just
#
# {'not_same': '0.02', 'same': '0.98'} bear with me but like it's already time
#  for me to go home right about it all
#  last night i had
#  the best time with my friends it's like
#
# {'not_same': '0.00', 'same': '1.00'} not even funny i needed that
#  so bad and coming home is just so fun
#  now and the fact that everyone just
#  got to be all together last night just
#
# {'not_same': '0.00', 'same': '1.00'} made me so [ __ ] happy i wanted to
#  change my flight so bad and stay here
#  longer but like i
#  can't that sucks but yeah i'm sitting in
#
# {'not_same': '0.33', 'same': '0.67'} aiden's old room now which is now my
#  room when i come home
#  here is a tour it's literally so tiny
#  yes these are stairs for many to go up
#
# {'not_same': '0.00', 'same': '1.00'} the bed cannot believe i'm stepping into
#  lax like this what a tragedy maybe i'll
#  rip all my nails off on the flight i
#  would really like to show you the bed
#
# {'not_same': '0.00', 'same': '1.00'} sheets i'm sleeping on right now though
#  they're kind of like my childhood bed
#  sheets but i kind of forgot what they
#  said on them but
#
# {'not_same': '0.00', 'same': '1.00'} take a good look at these these are
#  literally hawaii bed sheets
#  that i forgot that i slept on my entire
#  childhood like no [ __ ] [ __ ] i ended
#
# {'not_same': '0.00', 'same': '1.00'} up moving to hawaii and no wonder i'm
#  just absolutely obsessed with it like
#  these were the bed sheets that i slept
#  on all the time and growing up i'd never
#
# {'not_same': '0.05', 'same': '0.95'} even been to hawaii so i don't know why
#  my mom chose these but she did
#  and um this is me saying that like
#  everything happens for a reason all
#
# {'not_same': '0.00', 'same': '1.00'} right i'm gonna go now that makes me so
#  sad i don't want to be ending this vlog
#  at all i like hate that i didn't even
#  get to like do anything i had to wake up
#
# {'not_same': '0.01', 'same': '0.99'} from the hotel
#  and go right home and return my rental
#  car and i didn't get to go to like
#  brunch with all my friends i barely even
#
# {'not_same': '0.00', 'same': '1.00'} got to say bye to everyone well i said
#  bye to everyone last night but like i
#  didn't get to do anything fun today and
#  now i'm just like sad that this is how
#
# {'not_same': '0.00', 'same': '1.00'} my video is ending like it's just over
#  now but that's okay
#  because i'll be back wait also don't
#  forget to click the link in my bio to
#
# {'not_same': '0.00', 'same': '1.00'} get your current card today thank you
#  kern for sponsoring i love you
#  can't wait to see what mistake i make
#  with this card next time will only tell
#
# {'not_same': '0.01', 'same': '0.99'} i will see you guys in my next video i
#  hope you [ __ ] love this like i did
#  thank you for everything
#  so crazy how my life is now compared to
#
# {'not_same': '0.00', 'same': '1.00'} how it was living here and growing up
# here here
#  i'm just so [ __ ] grateful like thank
#  you guys for everything in this life
# like
# {'not_same': '0.00', 'same': '1.00'} like
#  seriously i do not know how i got so
#  lucky and coming home just makes me feel
#  like so connected with that too
#
# {'not_same': '0.01', 'same': '0.99'} especially when i go out in boston and
#  just meet so many people who watch my
#  videos the second i get out of my car
#  like i don't even know how that's a
#
# {'not_same': '0.02', 'same': '0.98'} thing either i met so many people
#  yesterday it's crazy even when i was
#  driving i had girls
#  wave at me from their cars so like i
# {'not_same': '0.01', 'same': '0.99'} don't know it just feels really good to
#  just like
#  reconnect and just remember where i came
#  from i don't know
#
# {'not_same': '0.01', 'same': '0.99'} thank you guys for [ __ ] everything
#  and i will see you in my next
#  video april like kind of might be fun
#  like i don't know like we'll see i have
#
# {'not_same': '0.31', 'same': '0.69'} some things planned that i think you
#  guys will like but
#  we'll [ __ ] see no more peace signs i
#  need to end this video i love you guys
#
# {'not_same': '0.01', 'same': '0.99'} so much oh my god i went to a sports
#  game in this video holy [ __ ]
# [ __ ]  bring that freaks out i put choices
# through
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 5>()
#       3     return itertools.zip_longest(fillvalue=fillvalue, *args)
#       5 for left_captions, right_captions in group(group(videos[2][1], 2), 2, []):
# ----> 6     left_text = ' '.join((caption['text'] for caption in left_captions))
#       7     right_text = ' '.join((caption['text'] for caption in right_captions))
#       8     inputs = tc_tokenizer(left_text, right_text)
#
# Input In [45], in <genexpr>(.0)
#       3     return itertools.zip_longest(fillvalue=fillvalue, *args)
#       5 for left_captions, right_captions in group(group(videos[2][1], 2), 2, []):
# ----> 6     left_text = ' '.join((caption['text'] for caption in left_captions))
#       7     right_text = ' '.join((caption['text'] for caption in right_captions))
#       8     inputs = tc_tokenizer(left_text, right_text)
#
# TypeError: 'NoneType' object is not subscriptable
